# %% [markdown]
# # AFASIA — Motor Pictórico + Gemma 4
# **Gemma 4 Good Hackathon | Kaggle 2026**
#
# Este notebook demonstra o uso de Gemma 4 multimodal para interpretação
# de imagens/pictogramas como auxílio à comunicação de pacientes com afasia.
#
# **Teoria:** Inteligência Topológica G = I + F (ver TEORIA.md)

# %%
# Célula 0 — Instalação
# TODO: ajustar conforme pacotes disponíveis no Kaggle
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'gradio', '-q'])
print('OK')

# %%
# Célula 1 — Configuração Gemma 4
# TODO: configurar autenticação via Kaggle Secrets
import os
# from kaggle_secrets import UserSecretsClient
# os.environ['GOOGLE_API_KEY'] = UserSecretsClient().get_secret('GOOGLE_API_KEY')
print('Configurar GOOGLE_API_KEY nas Secrets do Kaggle')

# %%
# Célula 2 — Pipeline principal
# TODO: implementar após gemma4_integration.py
# from model.gemma4_integration import PictoricInterpreter
# interpreter = PictoricInterpreter()
# result = interpreter.interpret('data/examples/agua.jpg', context='afasia de Broca')
# print(result)
print('TODO: implementar pipeline')

# %%
# Célula 3 — Avaliação quantitativa
# TODO: rodar sobre test_cases.json e calcular acurácia
print('TODO: avaliação')

# %% [markdown]
# ## Próximos Passos
# Ver `ROADMAP.md` — Fase 2 (Semana 3-4)
